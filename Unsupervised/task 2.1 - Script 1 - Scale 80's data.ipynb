# %% [markdown]
# # 1 Import Data

# %%
import pandas as pd
import os
from sklearn.preprocessing import StandardScaler

# %%
# Set the path to the main project folder
path = r'C:\Users\luis\Desktop\Carrer Foundry boot camp\Machine Learning Specialization\Data Sets'

# %%
# Import the orders data
df = pd.read_csv(os.path.join(path, 'Weather.csv'))

# %%
df.head()
# Out:
#        DATE  MONTH  BASEL_cloud_cover  BASEL_wind_speed  BASEL_humidity  \
# 0  19600101      1                  7               2.1            0.85
# 1  19600102      1                  6               2.1            0.84
# 2  19600103      1                  8               2.1            0.90
# 3  19600104      1                  3               2.1            0.92
# 4  19600105      1                  6               2.1            0.95
#
#    BASEL_pressure  BASEL_global_radiation  BASEL_precipitation  \
# 0           1.018                    0.32                 0.09
# 1           1.018                    0.36                 1.05
# 2           1.018                    0.18                 0.30
# 3           1.018                    0.58                 0.00
# 4           1.018                    0.65                 0.14
#
#    BASEL_snow_depth  BASEL_sunshine  ...  VALENTIA_cloud_cover  \
# 0                 0             0.7  ...                     5
# ...

# %%
#Reduce to just the mean temperatures
df_temp = df[['DATE', 'MONTH','BASEL_temp_mean',
 'BELGRADE_temp_mean',
 'BUDAPEST_temp_mean',
 'DEBILT_temp_mean',
 'DUSSELDORF_temp_mean',
 'GDANSK_temp_mean',
 'HEATHROW_temp_mean',
 'KASSEL_temp_mean',
 'LJUBLJANA_temp_mean',
 'MAASTRICHT_temp_mean',
 'MADRID_temp_mean',
 'MUNCHENB_temp_mean',
 'OSLO_temp_mean',
 'ROMA_temp_mean',
 'SONNBLICK_temp_mean',
 'STOCKHOLM_temp_mean',
 'TOURS_temp_mean',
 'VALENTIA_temp_mean']].copy()

# %%
df_temp
# Out:
#            DATE  MONTH  BASEL_temp_mean  BELGRADE_temp_mean  \
# 0      19600101      1              6.5                 3.7
# 1      19600102      1              6.1                 2.9
# 2      19600103      1              8.5                 3.1
# 3      19600104      1              6.3                 2.0
# 4      19600105      1              3.0                 2.0
# ...         ...    ...              ...                 ...
# 22945  20221027     10             15.9                18.2
# 22946  20221028     10             16.7                15.9
# 22947  20221029     10             16.7                13.4
# 22948  20221030     10             15.4                15.0
# 22949  20221031     10             13.5                14.4
#
#        BUDAPEST_temp_mean  DEBILT_temp_mean  DUSSELDORF_temp_mean  \
# 0                     2.4               9.3                  10.0
# 1                     2.3               7.7                   8.2
# ...

# %%
#Reduce your dataset to the 80's year
dfyear = df_temp[df_temp['DATE'].astype(str).str.contains('198')] 
dfyear
# Out:
#            DATE  MONTH  BASEL_temp_mean  BELGRADE_temp_mean  \
# 7305   19800101      1             -0.8                -0.6
# 7306   19800102      1             -1.7                -1.7
# 7307   19800103      1             -0.6                -2.5
# 7308   19800104      1             -0.9                -5.9
# 7309   19800105      1              3.0                -4.1
# ...         ...    ...              ...                 ...
# 10953  19891227     12             -0.9                 1.3
# 10954  19891228     12             -1.1                 1.1
# 10955  19891229     12             -1.7                -0.1
# 10956  19891230     12             -2.1                 0.2
# 10957  19891231     12             -2.2                -0.7
#
#        BUDAPEST_temp_mean  DEBILT_temp_mean  DUSSELDORF_temp_mean  \
# 7305                  0.3               0.9                   0.5
# 7306                  0.2              -0.4                   0.4
# ...

# %% [markdown]
# # 2 Scaling

# %%
# Select only the numerical columns
numerical_columns = dfyear.select_dtypes(include=['float64']).columns

# Adding the 'DATE' and 'MONTH' columns (ensure these columns exist in the DataFrame)
columns_to_include = ['DATE', 'MONTH'] + list(numerical_columns)

# Subset the dataframe to include numerical data and the 'DATE' and 'MONTH' columns
df_subset = dfyear[columns_to_include]

# %%
df_subset
# Out:
#            DATE  MONTH  BASEL_temp_mean  BELGRADE_temp_mean  \
# 7305   19800101      1             -0.8                -0.6
# 7306   19800102      1             -1.7                -1.7
# 7307   19800103      1             -0.6                -2.5
# 7308   19800104      1             -0.9                -5.9
# 7309   19800105      1              3.0                -4.1
# ...         ...    ...              ...                 ...
# 10953  19891227     12             -0.9                 1.3
# 10954  19891228     12             -1.1                 1.1
# 10955  19891229     12             -1.7                -0.1
# 10956  19891230     12             -2.1                 0.2
# 10957  19891231     12             -2.2                -0.7
#
#        BUDAPEST_temp_mean  DEBILT_temp_mean  DUSSELDORF_temp_mean  \
# 7305                  0.3               0.9                   0.5
# 7306                  0.2              -0.4                   0.4
# ...

# %%
#create scaler object using StandardScaler from sklearn.preprocessing
#StandardScaler assumes data is normally distributed and scales with a distribution
#around 0 and standard deviation of 1. Scaling happens independently with each variable.

scaler = StandardScaler()

# %%
# Fit and transform only the numerical columns (excluding 'DATE' and 'MONTH')
df_scaled_values = pd.DataFrame(scaler.fit_transform(df_subset[numerical_columns]), columns=numerical_columns)

# %%
# Add the 'DATE' and 'MONTH' columns back to the scaled dataframe
df_scaled = pd.concat([df_subset[['DATE', 'MONTH']].reset_index(drop=True), df_scaled_values.reset_index(drop=True)], axis=1)

# %%
# Display the first few rows of the scaled dataframe
df_scaled.head()
# Out:
#        DATE  MONTH  BASEL_temp_mean  BELGRADE_temp_mean  BUDAPEST_temp_mean  \
# 0  19800101      1        -1.444209           -1.428479           -1.269419
# 1  19800102      1        -1.566772           -1.554529           -1.281054
# 2  19800103      1        -1.416973           -1.646201           -1.571908
# 3  19800104      1        -1.457827           -2.035811           -1.874396
# 4  19800105      1        -0.926723           -1.829547           -2.130347
#
#    DEBILT_temp_mean  DUSSELDORF_temp_mean  GDANSK_temp_mean  \
# 0         -1.356022             -1.432024         -1.108021
# 1         -1.558895             -1.446441         -1.082513
# 2         -1.855402             -1.532946         -1.159035
# 3         -1.246783             -1.244597         -1.363093
# 4         -0.887854             -0.812074         -1.605411
#
#    HEATHROW_temp_mean  KASSEL_temp_mean  LJUBLJANA_temp_mean  \
# 0           -2.171863         -1.373112            -1.390799
# ...
